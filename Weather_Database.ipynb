# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Import the requests library.
import requests
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 775

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description= city_weather["weather"][0]["description"]
       
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | avarua
# Processing Record 2 of Set 1 | provideniya
# Processing Record 3 of Set 1 | arraial do cabo
# Processing Record 4 of Set 1 | kapaa
# Processing Record 5 of Set 1 | busselton
# Processing Record 6 of Set 1 | aklavik
# Processing Record 7 of Set 1 | buraydah
# Processing Record 8 of Set 1 | awash
# Processing Record 9 of Set 1 | hermanus
# Processing Record 10 of Set 1 | victoria
# Processing Record 11 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 12 of Set 1 | praia da vitoria
# Processing Record 13 of Set 1 | paucartambo
# City not found. Skipping...
# Processing Record 14 of Set 1 | sokolo
# Processing Record 15 of Set 1 | san cristobal
# Processing Record 16 of Set 1 | ponta delgada
# Processing Record 17 of Set 1 | albany
# Processing Record 18 of Set 1 | rikitea
# Processing Record 19 of Set 1 | bredasdorp
# Processing Record 20 of Set 1 | cape town
# Processing Record 21 of Set 1 | masty
# Processing Record 22 of Set 1 | isangel
# Processing Record 23 of Set 1 | half moon bay
# Processing Record 24 of Set 1 | jawhar
# Processing Record 25 of Set 1 | mahebourg
# Processing Record 26 of Set 1 | atuona
# Processing Record 27 of Set 1 | bluff
# Processing Record 28 of Set 1 | mildura
# Processing Record 29 of Set 1 | khatanga
# Processing Record 30 of Set 1 | yellowknife
# Processing Record 31 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 32 of Set 1 | bethel
# Processing Record 33 of Set 1 | benguela
# Processing Record 34 of Set 1 | venado tuerto
# Processing Record 35 of Set 1 | jamestown
# Processing Record 36 of Set 1 | buenaventura
# Processing Record 37 of Set 1 | todos santos
# Processing Record 38 of Set 1 | kazalinsk
# City not found. Skipping...
# Processing Record 39 of Set 1 | alofi
# Processing Record 40 of Set 1 | thompson
# Processing Record 41 of Set 1 | sao miguel do araguaia
# Processing Record 42 of Set 1 | obidos
# Processing Record 43 of Set 1 | vaini
# Processing Record 44 of Set 1 | labuhan
# Processing Record 45 of Set 1 | ushuaia
# Processing Record 46 of Set 1 | lasa
# Processing Record 47 of Set 1 | quatre cocos
# Processing Record 48 of Set 1 | esperance
# Processing Record 49 of Set 1 | ilulissat
# Processing Record 50 of Set 1 | georgetown
# Processing Record 1 of Set 2 | kodiak
# Processing Record 2 of Set 2 | mehamn
# Processing Record 3 of Set 2 | tuktoyaktuk
# Processing Record 4 of Set 2 | cururupu
# Processing Record 5 of Set 2 | port lincoln
# Processing Record 6 of Set 2 | hamilton
# Processing Record 7 of Set 2 | lorengau
# Processing Record 8 of Set 2 | marawi
# Processing Record 9 of Set 2 | carutapera
# Processing Record 10 of Set 2 | novyy urengoy
# Processing Record 11 of Set 2 | imeni poliny osipenko
# Processing Record 12 of Set 2 | sikandarpur
# Processing Record 13 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 14 of Set 2 | ugoofaaru
# Processing Record 15 of Set 2 | bathsheba
# Processing Record 16 of Set 2 | coahuayana
# Processing Record 17 of Set 2 | dixon
# Processing Record 18 of Set 2 | mataura
# Processing Record 19 of Set 2 | hornepayne
# Processing Record 20 of Set 2 | muhororo
# Processing Record 21 of Set 2 | papara
# Processing Record 22 of Set 2 | hobart
# Processing Record 23 of Set 2 | santa rosa
# Processing Record 24 of Set 2 | barrow
# Processing Record 25 of Set 2 | kahului
# Processing Record 26 of Set 2 | narsaq
# Processing Record 27 of Set 2 | pontes e lacerda
# Processing Record 28 of Set 2 | zhireken
# Processing Record 29 of Set 2 | saskylakh
# Processing Record 30 of Set 2 | punta arenas
# Processing Record 31 of Set 2 | soyo
# Processing Record 32 of Set 2 | aborlan
# Processing Record 33 of Set 2 | bodden town
# Processing Record 34 of Set 2 | nguiu
# City not found. Skipping...
# Processing Record 35 of Set 2 | hilo
# Processing Record 36 of Set 2 | qaanaaq
# Processing Record 37 of Set 2 | faya
# Processing Record 38 of Set 2 | port elizabeth
# Processing Record 39 of Set 2 | souillac
# Processing Record 40 of Set 2 | de-kastri
# Processing Record 41 of Set 2 | muzhi
# Processing Record 42 of Set 2 | port alfred
# Processing Record 43 of Set 2 | sarkand
# Processing Record 44 of Set 2 | namatanai
# Processing Record 45 of Set 2 | san quintin
# Processing Record 46 of Set 2 | saint-philippe
# Processing Record 47 of Set 2 | mar del plata
# Processing Record 48 of Set 2 | dakar
# Processing Record 49 of Set 2 | swan hill
# Processing Record 50 of Set 2 | haimen
# Processing Record 1 of Set 3 | puerto ayora
# Processing Record 2 of Set 3 | grindavik
# Processing Record 3 of Set 3 | uige
# Processing Record 4 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 5 of Set 3 | hithadhoo
# Processing Record 6 of Set 3 | araouane
# Processing Record 7 of Set 3 | san vicente
# Processing Record 8 of Set 3 | tisul
# Processing Record 9 of Set 3 | saldanha
# Processing Record 10 of Set 3 | longyearbyen
# Processing Record 11 of Set 3 | ahipara
# Processing Record 12 of Set 3 | hervey bay
# Processing Record 13 of Set 3 | sisimiut
# Processing Record 14 of Set 3 | krasnystaw
# Processing Record 15 of Set 3 | ixtapa
# Processing Record 16 of Set 3 | tondon
# Processing Record 17 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 18 of Set 3 | tasiilaq
# Processing Record 19 of Set 3 | kongwa
# Processing Record 20 of Set 3 | andros town
# Processing Record 21 of Set 3 | hovd
# Processing Record 22 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 23 of Set 3 | seymchan
# Processing Record 24 of Set 3 | kuusankoski
# Processing Record 25 of Set 3 | puerto leguizamo
# Processing Record 26 of Set 3 | nikolskoye
# Processing Record 27 of Set 3 | nome
# Processing Record 28 of Set 3 | lompoc
# Processing Record 29 of Set 3 | peniche
# Processing Record 30 of Set 3 | castro
# Processing Record 31 of Set 3 | samarai
# Processing Record 32 of Set 3 | saint-joseph
# Processing Record 33 of Set 3 | chapada dos guimaraes
# Processing Record 34 of Set 3 | mackenzie
# Processing Record 35 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 36 of Set 3 | shimoda
# Processing Record 37 of Set 3 | isaka
# Processing Record 38 of Set 3 | finschhafen
# Processing Record 39 of Set 3 | husavik
# Processing Record 40 of Set 3 | okha
# Processing Record 41 of Set 3 | butaritari
# Processing Record 42 of Set 3 | balikpapan
# Processing Record 43 of Set 3 | kavaratti
# Processing Record 44 of Set 3 | ryotsu
# Processing Record 45 of Set 3 | tazovskiy
# Processing Record 46 of Set 3 | skibbereen
# Processing Record 47 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 48 of Set 3 | liverpool
# Processing Record 49 of Set 3 | pevek
# Processing Record 50 of Set 3 | sioux lookout
# Processing Record 1 of Set 4 | flinders
# Processing Record 2 of Set 4 | shingu
# Processing Record 3 of Set 4 | burgdorf
# Processing Record 4 of Set 4 | atambua
# Processing Record 5 of Set 4 | sobolevo
# Processing Record 6 of Set 4 | constitucion
# Processing Record 7 of Set 4 | lethem
# Processing Record 8 of Set 4 | whitehorse
# Processing Record 9 of Set 4 | nanortalik
# Processing Record 10 of Set 4 | kununurra
# Processing Record 11 of Set 4 | sortavala
# Processing Record 12 of Set 4 | dunedin
# Processing Record 13 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 14 of Set 4 | saint-augustin
# Processing Record 15 of Set 4 | santo antonio do ica
# Processing Record 16 of Set 4 | berbera
# Processing Record 17 of Set 4 | lima
# Processing Record 18 of Set 4 | bahia honda
# Processing Record 19 of Set 4 | pontianak
# Processing Record 20 of Set 4 | pilar
# Processing Record 21 of Set 4 | east london
# Processing Record 22 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 23 of Set 4 | krasnovishersk
# Processing Record 24 of Set 4 | yagodnoye
# Processing Record 25 of Set 4 | bengkulu
# Processing Record 26 of Set 4 | tiksi
# Processing Record 27 of Set 4 | klyuchi
# Processing Record 28 of Set 4 | vila franca do campo
# Processing Record 29 of Set 4 | ilula
# Processing Record 30 of Set 4 | los andes
# Processing Record 31 of Set 4 | lagunas
# Processing Record 32 of Set 4 | porto belo
# Processing Record 33 of Set 4 | kathu
# Processing Record 34 of Set 4 | fez
# Processing Record 35 of Set 4 | talnakh
# Processing Record 36 of Set 4 | salta
# Processing Record 37 of Set 4 | ojinaga
# Processing Record 38 of Set 4 | severo-kurilsk
# Processing Record 39 of Set 4 | naziya
# Processing Record 40 of Set 4 | balimo
# City not found. Skipping...
# Processing Record 41 of Set 4 | toppenish
# Processing Record 42 of Set 4 | barcelos
# Processing Record 43 of Set 4 | camacha
# Processing Record 44 of Set 4 | covington
# Processing Record 45 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 46 of Set 4 | padang
# Processing Record 47 of Set 4 | namibe
# Processing Record 48 of Set 4 | fort-shevchenko
# Processing Record 49 of Set 4 | olafsvik
# Processing Record 50 of Set 4 | channel-port aux basques
# Processing Record 1 of Set 5 | launceston
# Processing Record 2 of Set 5 | verkhoshizhemye
# Processing Record 3 of Set 5 | batticaloa
# Processing Record 4 of Set 5 | coquimbo
# Processing Record 5 of Set 5 | upernavik
# Processing Record 6 of Set 5 | balvi
# Processing Record 7 of Set 5 | fortuna
# Processing Record 8 of Set 5 | vardo
# Processing Record 9 of Set 5 | dzilam gonzalez
# Processing Record 10 of Set 5 | ormara
# Processing Record 11 of Set 5 | katsuura
# Processing Record 12 of Set 5 | chokurdakh
# Processing Record 13 of Set 5 | pangnirtung
# Processing Record 14 of Set 5 | kaitangata
# Processing Record 15 of Set 5 | yarmouth
# Processing Record 16 of Set 5 | kupang
# Processing Record 17 of Set 5 | new norfolk
# Processing Record 18 of Set 5 | nabire
# Processing Record 19 of Set 5 | leshukonskoye
# Processing Record 20 of Set 5 | moissala
# Processing Record 21 of Set 5 | krasnoselkup
# Processing Record 22 of Set 5 | mitsamiouli
# Processing Record 23 of Set 5 | sakata
# Processing Record 24 of Set 5 | kortkeros
# Processing Record 25 of Set 5 | richards bay
# Processing Record 26 of Set 5 | jati
# Processing Record 27 of Set 5 | kasongo-lunda
# Processing Record 28 of Set 5 | saint george
# Processing Record 29 of Set 5 | ploemeur
# Processing Record 30 of Set 5 | serebryansk
# Processing Record 31 of Set 5 | comodoro rivadavia
# Processing Record 32 of Set 5 | tacoronte
# Processing Record 33 of Set 5 | bur gabo
# City not found. Skipping...
# Processing Record 34 of Set 5 | ancud
# Processing Record 35 of Set 5 | faanui
# Processing Record 36 of Set 5 | zhanakorgan
# Processing Record 37 of Set 5 | havre-saint-pierre
# Processing Record 38 of Set 5 | san patricio
# Processing Record 39 of Set 5 | gat
# Processing Record 40 of Set 5 | ahome
# Processing Record 41 of Set 5 | dikson
# Processing Record 42 of Set 5 | kisangani
# Processing Record 43 of Set 5 | erzurum
# Processing Record 44 of Set 5 | carroll
# Processing Record 45 of Set 5 | guerrero negro
# Processing Record 46 of Set 5 | boralday
# Processing Record 47 of Set 5 | sinjar
# Processing Record 48 of Set 5 | bac lieu
# Processing Record 49 of Set 5 | coos bay
# Processing Record 50 of Set 5 | yulara
# Processing Record 1 of Set 6 | susice
# Processing Record 2 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 3 of Set 6 | anadyr
# Processing Record 4 of Set 6 | nizhniy odes
# Processing Record 5 of Set 6 | tartki
# City not found. Skipping...
# Processing Record 6 of Set 6 | kieta
# Processing Record 7 of Set 6 | nanlong
# Processing Record 8 of Set 6 | tabou
# Processing Record 9 of Set 6 | ulladulla
# Processing Record 10 of Set 6 | umm bab
# Processing Record 11 of Set 6 | porec
# Processing Record 12 of Set 6 | den helder
# Processing Record 13 of Set 6 | touros
# Processing Record 14 of Set 6 | cabo san lucas
# Processing Record 15 of Set 6 | aloleng
# Processing Record 16 of Set 6 | raudeberg
# Processing Record 17 of Set 6 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 18 of Set 6 | malanje
# Processing Record 19 of Set 6 | belaya gora
# Processing Record 20 of Set 6 | rafsanjan
# Processing Record 21 of Set 6 | boquira
# Processing Record 22 of Set 6 | lebu
# Processing Record 23 of Set 6 | cidreira
# Processing Record 24 of Set 6 | odesskoye
# Processing Record 25 of Set 6 | caravelas
# Processing Record 26 of Set 6 | chagda
# City not found. Skipping...
# Processing Record 27 of Set 6 | hami
# Processing Record 28 of Set 6 | manta
# Processing Record 29 of Set 6 | isla vista
# Processing Record 30 of Set 6 | gazanjyk
# Processing Record 31 of Set 6 | kyabe
# Processing Record 32 of Set 6 | osoyoos
# Processing Record 33 of Set 6 | shakawe
# Processing Record 34 of Set 6 | ostrovnoy
# Processing Record 35 of Set 6 | sangar
# Processing Record 36 of Set 6 | plaster rock
# Processing Record 37 of Set 6 | tessalit
# Processing Record 38 of Set 6 | grand gaube
# Processing Record 39 of Set 6 | arlit
# Processing Record 40 of Set 6 | yumen
# Processing Record 41 of Set 6 | krasyukovskaya
# Processing Record 42 of Set 6 | vila velha
# Processing Record 43 of Set 6 | machali
# Processing Record 44 of Set 6 | moose factory
# Processing Record 45 of Set 6 | santa fe
# Processing Record 46 of Set 6 | korla
# Processing Record 47 of Set 6 | abha
# Processing Record 48 of Set 6 | one hundred mile house
# City not found. Skipping...
# Processing Record 49 of Set 6 | cozumel
# Processing Record 50 of Set 6 | oistins
# Processing Record 1 of Set 7 | alyangula
# Processing Record 2 of Set 7 | puri
# Processing Record 3 of Set 7 | daulatpur
# Processing Record 4 of Set 7 | sokoni
# Processing Record 5 of Set 7 | beyneu
# Processing Record 6 of Set 7 | tuatapere
# Processing Record 7 of Set 7 | high level
# Processing Record 8 of Set 7 | denpasar
# Processing Record 9 of Set 7 | dhola
# Processing Record 10 of Set 7 | hofn
# Processing Record 11 of Set 7 | muros
# Processing Record 12 of Set 7 | idlib
# Processing Record 13 of Set 7 | newtownards
# Processing Record 14 of Set 7 | carnarvon
# Processing Record 15 of Set 7 | jatai
# Processing Record 16 of Set 7 | dubuque
# Processing Record 17 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 18 of Set 7 | ambanja
# Processing Record 19 of Set 7 | bilibino
# Processing Record 20 of Set 7 | parrita
# Processing Record 21 of Set 7 | krasnyy yar
# Processing Record 22 of Set 7 | junction city
# Processing Record 23 of Set 7 | zabol
# Processing Record 24 of Set 7 | meyungs
# City not found. Skipping...
# Processing Record 25 of Set 7 | chuy
# Processing Record 26 of Set 7 | lazaro cardenas
# Processing Record 27 of Set 7 | anupgarh
# Processing Record 28 of Set 7 | valparaiso
# Processing Record 29 of Set 7 | port-gentil
# Processing Record 30 of Set 7 | acarau
# Processing Record 31 of Set 7 | hualmay
# Processing Record 32 of Set 7 | marienburg
# Processing Record 33 of Set 7 | lianzhou
# Processing Record 34 of Set 7 | palmer
# Processing Record 35 of Set 7 | kwinana
# Processing Record 36 of Set 7 | koygorodok
# Processing Record 37 of Set 7 | alekseyevsk
# Processing Record 38 of Set 7 | coruripe
# Processing Record 39 of Set 7 | honiara
# Processing Record 40 of Set 7 | danielskuil
# Processing Record 41 of Set 7 | bilma
# Processing Record 42 of Set 7 | erzin
# Processing Record 43 of Set 7 | port blair
# Processing Record 44 of Set 7 | inhambane
# Processing Record 45 of Set 7 | murdochville
# Processing Record 46 of Set 7 | galle
# Processing Record 47 of Set 7 | cedar city
# Processing Record 48 of Set 7 | straumen
# Processing Record 49 of Set 7 | ketchikan
# Processing Record 50 of Set 7 | kondinskoye
# Processing Record 1 of Set 8 | ginir
# Processing Record 2 of Set 8 | boljarovo
# City not found. Skipping...
# Processing Record 3 of Set 8 | progreso
# Processing Record 4 of Set 8 | la ronge
# Processing Record 5 of Set 8 | alto araguaia
# Processing Record 6 of Set 8 | aykhal
# Processing Record 7 of Set 8 | mount gambier
# Processing Record 8 of Set 8 | taiyuan
# Processing Record 9 of Set 8 | college
# Processing Record 10 of Set 8 | tupik
# Processing Record 11 of Set 8 | ahja
# Processing Record 12 of Set 8 | lavrentiya
# Processing Record 13 of Set 8 | geraldton
# Processing Record 14 of Set 8 | waipawa
# Processing Record 15 of Set 8 | salalah
# Processing Record 16 of Set 8 | zyryanka
# Processing Record 17 of Set 8 | santarem
# Processing Record 18 of Set 8 | kibala
# Processing Record 19 of Set 8 | basse-pointe
# Processing Record 20 of Set 8 | klaksvik
# Processing Record 21 of Set 8 | tias
# Processing Record 22 of Set 8 | aberdeen
# Processing Record 23 of Set 8 | sinjah
# City not found. Skipping...
# Processing Record 24 of Set 8 | atar
# Processing Record 25 of Set 8 | calvinia
# Processing Record 26 of Set 8 | bayonet point
# Processing Record 27 of Set 8 | bubaque
# Processing Record 28 of Set 8 | dubbo
# Processing Record 29 of Set 8 | ola
# Processing Record 30 of Set 8 | meulaboh
# Processing Record 31 of Set 8 | taga dzong
# City not found. Skipping...
# Processing Record 32 of Set 8 | ottumwa
# Processing Record 33 of Set 8 | ponta do sol
# Processing Record 34 of Set 8 | sedelnikovo
# City not found. Skipping...
# Processing Record 35 of Set 8 | cayenne
# Processing Record 36 of Set 8 | manokwari
# Processing Record 37 of Set 8 | gigmoto
# Processing Record 38 of Set 8 | beloha
# Processing Record 39 of Set 8 | shenkursk
# Processing Record 40 of Set 8 | bambous virieux
# Processing Record 41 of Set 8 | luderitz
# Processing Record 42 of Set 8 | yokadouma
# Processing Record 43 of Set 8 | kadykchan
# City not found. Skipping...
# Processing Record 44 of Set 8 | gordeyevka
# Processing Record 45 of Set 8 | airai
# Processing Record 46 of Set 8 | cam ranh
# Processing Record 47 of Set 8 | moyale
# Processing Record 48 of Set 8 | najran
# Processing Record 49 of Set 8 | mugumu
# Processing Record 50 of Set 8 | svetlaya
# Processing Record 1 of Set 9 | el tigre
# Processing Record 2 of Set 9 | riyadh
# Processing Record 3 of Set 9 | ngunguru
# Processing Record 4 of Set 9 | san carlos
# Processing Record 5 of Set 9 | xichang
# Processing Record 6 of Set 9 | labrea
# Processing Record 7 of Set 9 | swan river
# Processing Record 8 of Set 9 | bialogard
# Processing Record 9 of Set 9 | torbay
# Processing Record 10 of Set 9 | sitka
# Processing Record 11 of Set 9 | shizunai
# Processing Record 12 of Set 9 | batagay-alyta
# Processing Record 13 of Set 9 | pisco
# Processing Record 14 of Set 9 | dien bien
# City not found. Skipping...
# Processing Record 15 of Set 9 | oriximina
# Processing Record 16 of Set 9 | rocha
# Processing Record 17 of Set 9 | kloulklubed
# Processing Record 18 of Set 9 | ouro branco
# Processing Record 19 of Set 9 | sistranda
# Processing Record 20 of Set 9 | george
# Processing Record 21 of Set 9 | tulum
# Processing Record 22 of Set 9 | harper
# Processing Record 23 of Set 9 | jacareacanga
# Processing Record 24 of Set 9 | vostok
# Processing Record 25 of Set 9 | kruisfontein
# Processing Record 26 of Set 9 | chapais
# Processing Record 27 of Set 9 | rosario oeste
# Processing Record 28 of Set 9 | xuchang
# Processing Record 29 of Set 9 | brae
# Processing Record 30 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 31 of Set 9 | champerico
# Processing Record 32 of Set 9 | nuuk
# Processing Record 33 of Set 9 | aranos
# Processing Record 34 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 35 of Set 9 | lagoa
# Processing Record 36 of Set 9 | dalianwan
# Processing Record 37 of Set 9 | karratha
# Processing Record 38 of Set 9 | mount isa
# Processing Record 39 of Set 9 | san luis
# Processing Record 40 of Set 9 | iwaki
# Processing Record 41 of Set 9 | taksimo
# Processing Record 42 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 43 of Set 9 | doha
# Processing Record 44 of Set 9 | balsas
# Processing Record 45 of Set 9 | lalin
# Processing Record 46 of Set 9 | virginia beach
# Processing Record 47 of Set 9 | rawson
# Processing Record 48 of Set 9 | norman wells
# Processing Record 49 of Set 9 | aldan
# Processing Record 50 of Set 9 | naze
# Processing Record 1 of Set 10 | veshkayma
# Processing Record 2 of Set 10 | ksenyevka
# City not found. Skipping...
# Processing Record 3 of Set 10 | rassvet
# Processing Record 4 of Set 10 | shumskiy
# Processing Record 5 of Set 10 | anito
# Processing Record 6 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 7 of Set 10 | cockburn town
# Processing Record 8 of Set 10 | kapit
# Processing Record 9 of Set 10 | eyl
# Processing Record 10 of Set 10 | tigzirt
# Processing Record 11 of Set 10 | koson
# Processing Record 12 of Set 10 | san isidro
# Processing Record 13 of Set 10 | aksu
# Processing Record 14 of Set 10 | marquette
# Processing Record 15 of Set 10 | ribeira grande
# Processing Record 16 of Set 10 | omboue
# Processing Record 17 of Set 10 | deming
# Processing Record 18 of Set 10 | bengkalis
# City not found. Skipping...
# Processing Record 19 of Set 10 | novoilinsk
# Processing Record 20 of Set 10 | severiano melo
# Processing Record 21 of Set 10 | natal
# Processing Record 22 of Set 10 | lakes entrance
# Processing Record 23 of Set 10 | magaria
# Processing Record 24 of Set 10 | sur
# Processing Record 25 of Set 10 | sumenep
# Processing Record 26 of Set 10 | bonavista
# Processing Record 27 of Set 10 | henties bay
# Processing Record 28 of Set 10 | muncar
# Processing Record 29 of Set 10 | antsohihy
# Processing Record 30 of Set 10 | huntsville
# Processing Record 31 of Set 10 | fairbanks
# Processing Record 32 of Set 10 | horodok
# Processing Record 33 of Set 10 | saint-pascal
# City not found. Skipping...
# Processing Record 34 of Set 10 | satitoa
# City not found. Skipping...
# Processing Record 35 of Set 10 | yarega
# Processing Record 36 of Set 10 | bolshaya martynovka
# Processing Record 37 of Set 10 | tukrah
# Processing Record 38 of Set 10 | chicama
# Processing Record 39 of Set 10 | san rafael del sur
# Processing Record 40 of Set 10 | kangaatsiaq
# Processing Record 41 of Set 10 | iquique
# Processing Record 42 of Set 10 | pauini
# Processing Record 43 of Set 10 | broome
# Processing Record 44 of Set 10 | kenai
# Processing Record 45 of Set 10 | nantucket
# Processing Record 46 of Set 10 | champoton
# Processing Record 47 of Set 10 | ust-maya
# Processing Record 48 of Set 10 | galich
# Processing Record 49 of Set 10 | mao
# Processing Record 50 of Set 10 | westport
# Processing Record 1 of Set 11 | wasilla
# Processing Record 2 of Set 11 | chiang klang
# Processing Record 3 of Set 11 | miechow
# Processing Record 4 of Set 11 | egvekinot
# Processing Record 5 of Set 11 | rochegda
# Processing Record 6 of Set 11 | vigrestad
# Processing Record 7 of Set 11 | burica
# City not found. Skipping...
# Processing Record 8 of Set 11 | evensk
# Processing Record 9 of Set 11 | banda aceh
# Processing Record 10 of Set 11 | winnemucca
# Processing Record 11 of Set 11 | uzventis
# Processing Record 12 of Set 11 | cherskiy
# Processing Record 13 of Set 11 | rio gallegos
# Processing Record 14 of Set 11 | kamenka
# Processing Record 15 of Set 11 | iskateley
# Processing Record 16 of Set 11 | buchanan
# Processing Record 17 of Set 11 | chkalovskoye
# Processing Record 18 of Set 11 | sambava
# Processing Record 19 of Set 11 | marzuq
# Processing Record 20 of Set 11 | viedma
# Processing Record 21 of Set 11 | diamantino
# Processing Record 22 of Set 11 | kashi
# Processing Record 23 of Set 11 | manicore
# Processing Record 24 of Set 11 | songjianghe
# Processing Record 25 of Set 11 | great yarmouth
# Processing Record 26 of Set 11 | san policarpo
# Processing Record 27 of Set 11 | utiel
# Processing Record 28 of Set 11 | kaseda
# Processing Record 29 of Set 11 | clyde river
# Processing Record 30 of Set 11 | risti
# Processing Record 31 of Set 11 | turayf
# Processing Record 32 of Set 11 | port hardy
# Processing Record 33 of Set 11 | barhi
# Processing Record 34 of Set 11 | cazones
# Processing Record 35 of Set 11 | sao joao da barra
# Processing Record 36 of Set 11 | laguna
# Processing Record 37 of Set 11 | tabora
# Processing Record 38 of Set 11 | madimba
# Processing Record 39 of Set 11 | port keats
# Processing Record 40 of Set 11 | slave lake
# Processing Record 41 of Set 11 | puerto boyaca
# Processing Record 42 of Set 11 | kidodi
# Processing Record 43 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 44 of Set 11 | ijaki
# City not found. Skipping...
# Processing Record 45 of Set 11 | mason city
# Processing Record 46 of Set 11 | yerbogachen
# Processing Record 47 of Set 11 | sorland
# Processing Record 48 of Set 11 | addi ugri
# City not found. Skipping...
# Processing Record 49 of Set 11 | muisne
# Processing Record 50 of Set 11 | wuzhou
# Processing Record 1 of Set 12 | pasighat
# Processing Record 2 of Set 12 | poum
# Processing Record 3 of Set 12 | margate
# Processing Record 4 of Set 12 | hasaki
# Processing Record 5 of Set 12 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 6 of Set 12 | kampot
# Processing Record 7 of Set 12 | barra patuca
# Processing Record 8 of Set 12 | aban
# Processing Record 9 of Set 12 | kolondieba
# Processing Record 10 of Set 12 | katangli
# Processing Record 11 of Set 12 | talgar
# Processing Record 12 of Set 12 | maarianhamina
# Processing Record 13 of Set 12 | douazeci si trei august
# Processing Record 14 of Set 12 | roma
# Processing Record 15 of Set 12 | dong xoai
# Processing Record 16 of Set 12 | isabela
# Processing Record 17 of Set 12 | northam
# Processing Record 18 of Set 12 | winneba
# Processing Record 19 of Set 12 | vrangel
# Processing Record 20 of Set 12 | hambantota
# Processing Record 21 of Set 12 | bradford
# Processing Record 22 of Set 12 | elesbao veloso
# Processing Record 23 of Set 12 | ngama
# Processing Record 24 of Set 12 | bijar
# Processing Record 25 of Set 12 | werota
# Processing Record 26 of Set 12 | muana
# Processing Record 27 of Set 12 | iqaluit
# Processing Record 28 of Set 12 | luba
# Processing Record 29 of Set 12 | maragogi
# Processing Record 30 of Set 12 | karkaralinsk
# City not found. Skipping...
# Processing Record 31 of Set 12 | humen
# Processing Record 32 of Set 12 | chiredzi
# Processing Record 33 of Set 12 | satun
# Processing Record 34 of Set 12 | kanniyakumari
# Processing Record 35 of Set 12 | safranbolu
# Processing Record 36 of Set 12 | khandbari
# Processing Record 37 of Set 12 | victor harbor
# Processing Record 38 of Set 12 | asosa
# Processing Record 39 of Set 12 | beringovskiy
# Processing Record 40 of Set 12 | miandrivazo
# Processing Record 41 of Set 12 | makakilo city
# Processing Record 42 of Set 12 | kaeo
# Processing Record 43 of Set 12 | toftir
# City not found. Skipping...
# Processing Record 44 of Set 12 | lofthus
# Processing Record 45 of Set 12 | port macquarie
# Processing Record 46 of Set 12 | gornopravdinsk
# Processing Record 47 of Set 12 | larsnes
# Processing Record 48 of Set 12 | ambon
# Processing Record 49 of Set 12 | mantua
# Processing Record 50 of Set 12 | kotelnich
# Processing Record 1 of Set 13 | ozinki
# Processing Record 2 of Set 13 | kavieng
# Processing Record 3 of Set 13 | tuysarkan
# City not found. Skipping...
# Processing Record 4 of Set 13 | khorixas
# Processing Record 5 of Set 13 | cascais
# Processing Record 6 of Set 13 | talara
# Processing Record 7 of Set 13 | kuche
# City not found. Skipping...
# Processing Record 8 of Set 13 | khartoum
# Processing Record 9 of Set 13 | pahrump
# Processing Record 10 of Set 13 | umm durman
# City not found. Skipping...
# Processing Record 11 of Set 13 | medicine hat
# Processing Record 12 of Set 13 | pierre
# Processing Record 13 of Set 13 | urumqi
# Processing Record 14 of Set 13 | cabildo
# Processing Record 15 of Set 13 | kiama
# Processing Record 16 of Set 13 | ternate
# Processing Record 17 of Set 13 | te anau
# Processing Record 18 of Set 13 | kuala kedah
# Processing Record 19 of Set 13 | itambe
# Processing Record 20 of Set 13 | villa hayes
# Processing Record 21 of Set 13 | avera
# Processing Record 22 of Set 13 | polovinnoye
# Processing Record 23 of Set 13 | bababe
# City not found. Skipping...
# Processing Record 24 of Set 13 | freeport
# Processing Record 25 of Set 13 | abu samrah
# Processing Record 26 of Set 13 | barreirinhas
# Processing Record 27 of Set 13 | bafq
# Processing Record 28 of Set 13 | mutoko
# Processing Record 29 of Set 13 | dargaville
# Processing Record 30 of Set 13 | puerto ayacucho
# Processing Record 31 of Set 13 | tahta
# Processing Record 32 of Set 13 | necochea
# Processing Record 33 of Set 13 | manyana
# Processing Record 34 of Set 13 | waraseoni
# Processing Record 35 of Set 13 | petropavlovsk-kamchatskiy
# Processing Record 36 of Set 13 | sola
# Processing Record 37 of Set 13 | capaci
# Processing Record 38 of Set 13 | manzanillo
# Processing Record 39 of Set 13 | coxim
# Processing Record 40 of Set 13 | boqueirao
# Processing Record 41 of Set 13 | amahai
# Processing Record 42 of Set 13 | mocuba
# Processing Record 43 of Set 13 | xingyi
# Processing Record 44 of Set 13 | mayo
# Processing Record 45 of Set 13 | mangaratiba
# Processing Record 46 of Set 13 | nadym
# Processing Record 47 of Set 13 | borda da mata
# Processing Record 48 of Set 13 | sabang
# Processing Record 49 of Set 13 | puerto escondido
# Processing Record 50 of Set 13 | wanning
# Processing Record 1 of Set 14 | cantapoy
# Processing Record 2 of Set 14 | black river
# Processing Record 3 of Set 14 | brewster
# Processing Record 4 of Set 14 | tucumcari
# Processing Record 5 of Set 14 | toktogul
# Processing Record 6 of Set 14 | alice springs
# Processing Record 7 of Set 14 | muli
# Processing Record 8 of Set 14 | billings
# Processing Record 9 of Set 14 | bitung
# Processing Record 10 of Set 14 | huarmey
# Processing Record 11 of Set 14 | kaliua
# Processing Record 12 of Set 14 | ati
# Processing Record 13 of Set 14 | mrirt
# City not found. Skipping...
# Processing Record 14 of Set 14 | grootfontein
# Processing Record 15 of Set 14 | kimbe
# Processing Record 16 of Set 14 | magistralnyy
# Processing Record 17 of Set 14 | bulgan
# Processing Record 18 of Set 14 | dingle
# Processing Record 19 of Set 14 | altamont
# Processing Record 20 of Set 14 | dutse
# Processing Record 21 of Set 14 | sao filipe
# Processing Record 22 of Set 14 | ballina
# Processing Record 23 of Set 14 | goderich
# Processing Record 24 of Set 14 | bandarbeyla
# Processing Record 25 of Set 14 | maumere
# Processing Record 26 of Set 14 | marcona
# City not found. Skipping...
# Processing Record 27 of Set 14 | minot
# Processing Record 28 of Set 14 | berlevag
# Processing Record 29 of Set 14 | purmerend
# Processing Record 30 of Set 14 | erenhot
# Processing Record 31 of Set 14 | bethal
# Processing Record 32 of Set 14 | siayan
# Processing Record 33 of Set 14 | kharan
# Processing Record 34 of Set 14 | port hedland
# Processing Record 35 of Set 14 | ilorin
# Processing Record 36 of Set 14 | nurota
# Processing Record 37 of Set 14 | barra do garcas
# Processing Record 38 of Set 14 | gradignan
# Processing Record 39 of Set 14 | nakusp
# Processing Record 40 of Set 14 | bridgetown
# Processing Record 41 of Set 14 | bandon
# Processing Record 42 of Set 14 | ipixuna
# Processing Record 43 of Set 14 | adrar
# Processing Record 44 of Set 14 | ponte de sor
# Processing Record 45 of Set 14 | eldikan
# City not found. Skipping...
# Processing Record 46 of Set 14 | cape coast
# Processing Record 47 of Set 14 | podgornoye
# Processing Record 48 of Set 14 | ayagoz
# Processing Record 49 of Set 14 | los llanos de aridane
# Processing Record 50 of Set 14 | goycay
# City not found. Skipping...
# Processing Record 1 of Set 15 | wanaka
# Processing Record 2 of Set 15 | murgab
# Processing Record 3 of Set 15 | tayu
# Processing Record 4 of Set 15 | wonthaggi
# Processing Record 5 of Set 15 | ciechocinek
# Processing Record 6 of Set 15 | naryan-mar
# Processing Record 7 of Set 15 | cicero dantas
# Processing Record 8 of Set 15 | northport
# Processing Record 9 of Set 15 | kifri
# Processing Record 10 of Set 15 | tairua
# Processing Record 11 of Set 15 | paamiut
# Processing Record 12 of Set 15 | sulphur springs
# Processing Record 13 of Set 15 | tura
# Processing Record 14 of Set 15 | basco
# Processing Record 15 of Set 15 | mackay
# Processing Record 16 of Set 15 | saint anthony
# Processing Record 17 of Set 15 | port hawkesbury
# Processing Record 18 of Set 15 | wulanhaote
# City not found. Skipping...
# Processing Record 19 of Set 15 | topolobampo
# Processing Record 20 of Set 15 | tibiri
# Processing Record 21 of Set 15 | bongandanga
# Processing Record 22 of Set 15 | mareeba
# Processing Record 23 of Set 15 | urshelskiy
# Processing Record 24 of Set 15 | puerto penasco
# Processing Record 25 of Set 15 | sorong
# Processing Record 26 of Set 15 | kirakira
# Processing Record 27 of Set 15 | sumbawa
# City not found. Skipping...
# Processing Record 28 of Set 15 | shebekino
# Processing Record 29 of Set 15 | saint-francois
# Processing Record 30 of Set 15 | hecelchakan
# Processing Record 31 of Set 15 | marsa matruh
# Processing Record 32 of Set 15 | kurri kurri
# Processing Record 33 of Set 15 | carballo
# Processing Record 34 of Set 15 | juifang
# City not found. Skipping...
# Processing Record 35 of Set 15 | nemuro
# Processing Record 36 of Set 15 | nanakuli
# Processing Record 37 of Set 15 | dinsor
# City not found. Skipping...
# Processing Record 38 of Set 15 | andselv
# City not found. Skipping...
# Processing Record 39 of Set 15 | vikarabad
# Processing Record 40 of Set 15 | bahile
# Processing Record 41 of Set 15 | kathmandu
# Processing Record 42 of Set 15 | jacqueville
# Processing Record 43 of Set 15 | teya
# Processing Record 44 of Set 15 | arari
# Processing Record 45 of Set 15 | korem
# Processing Record 46 of Set 15 | nushki
# Processing Record 47 of Set 15 | moron
# Processing Record 48 of Set 15 | komatipoort
# Processing Record 49 of Set 15 | lebedyn
# Processing Record 50 of Set 15 | araguaina
# Processing Record 1 of Set 16 | merauke
# Processing Record 2 of Set 16 | kralendijk
# Processing Record 3 of Set 16 | ko samui
# Processing Record 4 of Set 16 | portland
# Processing Record 5 of Set 16 | gilbues
# Processing Record 6 of Set 16 | goure
# Processing Record 7 of Set 16 | alexandria
# Processing Record 8 of Set 16 | xifeng
# Processing Record 9 of Set 16 | zhengjiatun
# Processing Record 10 of Set 16 | itarema
# Processing Record 11 of Set 16 | juneau
# Processing Record 12 of Set 16 | daru
# Processing Record 13 of Set 16 | polis
# Processing Record 14 of Set 16 | jiayuguan
# Processing Record 15 of Set 16 | bimbo
# Processing Record 16 of Set 16 | road town
# Processing Record 17 of Set 16 | nakhon phanom
# Processing Record 18 of Set 16 | novopavlovka
# Processing Record 19 of Set 16 | cottbus
# Processing Record 20 of Set 16 | worland
# Processing Record 21 of Set 16 | san francisco
# Processing Record 22 of Set 16 | lata
# Processing Record 23 of Set 16 | mangrol
# Processing Record 24 of Set 16 | leningradskiy
# Processing Record 25 of Set 16 | ahumada
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0       Bluff -46.6000  168.3333     51.94        81         100        2.95
# 1    Hermanus -34.4187   19.2345     60.91        80          45       15.28
# 2     Birjand  32.8663   59.2211     30.67        37           0        0.00
# 3    Lakatoro -16.0999  167.4164     79.54        72          99        4.97
# 4   Cape Town -33.9258   18.4232     62.11        66           0       12.66
# 5  Bredasdorp -34.5322   20.0403     57.27        77          94       12.86
# 6   Inhambane -23.8650   35.3833     75.18        94          75        5.75
# 7      Atuona  -9.8000 -139.0333     78.37        75           4       14.85
# 8     Dunedin -45.8742  170.5036     58.35        78         100        4.63
# 9       Erzin  36.9559   36.2000     54.32        85         100        1.63
#
#   Country Current Description
# 0      NZ     overcast clouds
# 1      ZA    scattered clouds
# 2      IR           clear sky
# 3      VU     overcast clouds
# 4      ZA           clear sky
# 5      ZA          light rain
# 6      MZ          light rain
# 7      PF           clear sky
# 8      NZ       moderate rain
# 9      TR          light rain

# %%
# Reorder the columns

new_column_order = [ "City" , "Country" , "Lat" , "Lng" , "Max Temp", "Humidity", "Cloudiness", "Wind Speed","Current Description"]

city_data_df = city_data_df [new_column_order]

city_data_df.head(10)
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Bluff      NZ -46.6000  168.3333     51.94        81         100
# 1    Hermanus      ZA -34.4187   19.2345     60.91        80          45
# 2     Birjand      IR  32.8663   59.2211     30.67        37           0
# 3    Lakatoro      VU -16.0999  167.4164     79.54        72          99
# 4   Cape Town      ZA -33.9258   18.4232     62.11        66           0
# 5  Bredasdorp      ZA -34.5322   20.0403     57.27        77          94
# 6   Inhambane      MZ -23.8650   35.3833     75.18        94          75
# 7      Atuona      PF  -9.8000 -139.0333     78.37        75           4
# 8     Dunedin      NZ -45.8742  170.5036     58.35        78         100
# 9       Erzin      TR  36.9559   36.2000     54.32        85         100
#
#    Wind Speed Current Description
# 0        2.95     overcast clouds
# 1       15.28    scattered clouds
# 2        0.00           clear sky
# 3        4.97     overcast clouds
# 4       12.66           clear sky
# 5       12.86          light rain
# 6        5.75          light rain
# 7       14.85           clear sky
# 8        4.63       moderate rain
# 9        1.63          light rain

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
